# %%
import hepmcanalysis
import ROOT
import rootnotes

# %%
h = ROOT.TH1F('test','test',20,0,50)
# Out:
# TROOT::Append:0: RuntimeWarning: Replacing existing TH1: test (Potential memory leak).

# %%
for e in hepmcanalysis.readhepmc('../../atlas/newrecastplugin/sampleworkdir/what_unshowered.hepmc'):
    h.Fill(len(e.particles()))

# %%
c = rootnotes.default_canvas()

# %%
h.Draw()

# %%
c
# Out:
# <ROOT.TCanvas object ("icanvas") at 0x7ff9265c1140>
